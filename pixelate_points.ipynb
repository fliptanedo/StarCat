# %%
import numpy as np
import matplotlib.pylab as plt

# %matplotlib notebook

# %%
pts = np.random.random((2,1000))
plt.plot(pts[0],pts[1],'k.',markersize=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
imgsize = 256
img = np.zeros((imgsize,imgsize))

h = np.histogram2d(imgsize*pts[0],imgsize*pts[1],bins=imgsize)

# %%
plt.figure()
plt.imshow(h[0],cmap="Greys")
# Out:
# <img src="data:image/png;base64,..." width="640">
